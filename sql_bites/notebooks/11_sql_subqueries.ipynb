# %%
# %load_ext sql

# %%
# %sql postgresql+psycopg://localhost:5432/intro_to_sql_for_analytics

# %% [markdown]
# ## SQL Subqueries

# %% [markdown]
# ### FROM Subqueries

# %% [markdown]
# Calculate the average age of each athlete.
#
# First we need to calculate the age of each athlete:

# %%
# %%sql
# SELECT *
# FROM athletes
# LIMIT 5;
# Out:
#  * postgresql+psycopg://localhost:5432/intro_to_sql_for_analytics
# 5 rows affected.
# [(0, 'AAJIM Munkhbat', 'Mongolia', 'MGL', 'Judo', 'JUD', datetime.date(1989, 1, 25), 'Male'),
#  (1, 'ABARZA Alberto', 'Chile', 'CHI', 'Swimming', 'SWM', datetime.date(1984, 12, 11), 'Male'),
#  (2, 'ABASLI Namig', 'Azerbaijan', 'AZE', 'Judo', 'JUD', datetime.date(1997, 9, 12), 'Male'),
#  (3, 'ABASSI Mostefa', 'Algeria', 'ALG', 'Wheelchair Basketball', 'WBK', datetime.date(1977, 9, 25), 'Male'),
#  (4, 'ABBAD Abderraouf', 'Algeria', 'ALG', 'Wheelchair Basketball', 'WBK', datetime.date(1986, 10, 27), 'Male')]

# %% [markdown]
# DATE_PART is used to return part of a date here we use it get the year
#
# Our subquery is used to calculate the age of each athlete

# %%
# %%sql
#
# SELECT
# name,
# sport,
# DATE_PART('year', CURRENT_DATE) - DATE_PART('year', date_of_birth) as age
# FROM athletes
# LIMIT 15;
# Out:
#  * postgresql+psycopg://localhost:5432/intro_to_sql_for_analytics
# 15 rows affected.
# [('AAJIM Munkhbat', 'Judo', 34.0),
#  ('ABARZA Alberto', 'Swimming', 39.0),
#  ('ABASLI Namig', 'Judo', 26.0),
#  ('ABASSI Mostefa', 'Wheelchair Basketball', 46.0),
#  ('ABBAD Abderraouf', 'Wheelchair Basketball', 37.0),
#  ('ABDALLA Ashraf', 'Sitting Volleyball', 49.0),
#  ('ABOUELYAZEID Mohamed', 'Sitting Volleyball', 44.0),
#  ('ABDELALI Samiha', 'Wheelchair Basketball', 35.0),
#  ('ABDELAZIZ Gihan', 'Powerlifting', 49.0),
#  ('ELKHARSA Ahmed', 'Sitting Volleyball', 26.0),
#  ('ABDELHADY Hany', 'Powerlifting', 43.0),
#  ('ABDELLAOUI Cherine', 'Judo', 25.0),
#  ('ABDELLATIF Abdelnaby', 'Sitting Volleyball', 51.0),
#  ('ABDELLI Rima', 'Athletics', 35.0),
#  ('ABDELMAJID Taha', 'Powerlifting', 36.0)]

# %% [markdown]
# Now we have the ages for each athlete we can use AVG to get the average age.
#
# Our outer query will look like this:
#
#
# ```sql
# SELECT subquery_result.sport, AVG(subquery_result.age) AS average_age
#   FROM (...) subquery_result
#   GROUP BY subquery_result.sport
#   ORDER BY average_age;
# ```
#
#
#
# If we combine our subquery and outer query we get:

# %%
# %%sql
#
# SELECT subquery_result.sport, AVG(subquery_result.age) AS average_age
#   FROM (
#     SELECT
#       name,
#       sport,
#       DATE_PART('year', CURRENT_DATE) - DATE_PART('year', date_of_birth) as age
#       FROM athletes
#   ) subquery_result
#   GROUP BY subquery_result.sport
#   ORDER BY average_age DESC;
# Out:
#  * postgresql+psycopg://localhost:5432/intro_to_sql_for_analytics
# 23 rows affected.
# [('Shooting', 41.86363636363637),
#  ('Equestrian', 40.506493506493506),
#  ('Cycling Road', 39.798122065727696),
#  ('Archery', 39.75539568345324),
#  ('Powerlifting', 38.146067415730336),
#  ('Sitting Volleyball', 37.213903743315505),
#  ('Triathlon', 36.975),
#  ('Table Tennis', 36.780575539568346),
#  ('Wheelchair Fencing', 36.729166666666664),
#  ('Canoe Sprint', 36.43956043956044),
#  ('Wheelchair Rugby', 36.26086956521739),
#  ('Cycling Track', 36.18260869565217),
#  ('Rowing', 35.675925925925924),
#  ('Wheelchair Tennis', 35.66346153846154),
#  ('Badminton', 35.4),
#  ('Boccia', 35.03508771929825),
#  ('Judo', 33.588235294117645),
#  ('Football 5-a-side', 33.51282051282051),
#  ('Wheelchair Basketball', 33.01145038167939),
#  ('Athletics', 32.14886164623468),
#  ('Goalball', 30.949152542372882),
#  ('Taekwondo', 30.56338028169014),
#  ('Swimming', 27.799668874172184)]

# %% [markdown]
# What if we wanted to find the average age for each medal? We'd have to throw a JOIN in as well!
#
# Let's do the subquery first.

# %%
# %%sql
#
# SELECT
#     medals.medal,
#     DATE_PART('year', CURRENT_DATE) - DATE_PART('year', athletes.date_of_birth) as age
#     FROM athletes INNER JOIN medals
#     ON athletes.name = medals.name
#     AND athletes.sport = medals.sport
#     LIMIT 15;
# Out:
#  * postgresql+psycopg://localhost:5432/intro_to_sql_for_analytics
# 15 rows affected.
# [('Silver Medal', 39.0),
#  ('Silver Medal', 39.0),
#  ('Gold Medal', 39.0),
#  ('Bronze Medal', 26.0),
#  ('Bronze Medal', 43.0),
#  ('Gold Medal', 25.0),
#  ('Bronze Medal', 54.0),
#  ('Gold Medal', 54.0),
#  ('Bronze Medal', 38.0),
#  ('Gold Medal', 38.0),
#  ('Silver Medal', 22.0),
#  ('Bronze Medal', 49.0),
#  ('Silver Medal', 34.0),
#  ('Bronze Medal', 38.0),
#  ('Bronze Medal', 52.0)]

# %% [markdown]
# The outer query combined with the subquery:

# %%
# %%sql
#
# SELECT subquery_result.medal, AVG(subquery_result.age) as average_age
# FROM (
#   SELECT
#     medals.medal,
#     DATE_PART('year', CURRENT_DATE) - DATE_PART('year', athletes.date_of_birth) as age
#     FROM athletes INNER JOIN medals
#     ON athletes.name = medals.name
#     AND athletes.sport = medals.sport
# ) subquery_result
# GROUP BY medal
# ORDER BY average_age DESC;
# Out:
#  * postgresql+psycopg://localhost:5432/intro_to_sql_for_analytics
# 3 rows affected.
# [('Bronze Medal', 33.05710491367862),
#  ('Silver Medal', 32.65123010130246),
#  ('Gold Medal', 31.70487106017192)]

# %% [markdown]
# ## WHERE Subqueries

# %% [markdown]
# If you wanted to get a list of all the athletes who had won a gold medal, you could use a WHERE subquery, like this

# %%
# %%sql
#
# SELECT name
# FROM athletes
# WHERE name IN (
#     SELECT name
#     FROM medals
#     WHERE medal = 'Gold Medal'
# )
# LIMIT 20;
# Out:
#  * postgresql+psycopg://localhost:5432/intro_to_sql_for_analytics
# 20 rows affected.
# [('ABARZA Alberto',),
#  ('ABDELLAOUI Cherine',),
#  ('ABLINGER Walter',),
#  ('ABRAHAM GEBRU Daniel',),
#  ('ABRAHAM GEBRU Daniel',),
#  ('ADAMS Lisa',),
#  ('AFROOZ Saeid',),
#  ('ALARYANI Abdulla Sultan',),
#  ('ALCOTT Dylan',),
#  ('ALI Haider',),
#  ('ALI POUR Meisam',),
#  ('ALIPOURIAN Davoud',),
#  ('ALONSO MORALES Michelle',),
#  ('ALTUNOLUK Sevda',),
#  ('ALTUNOLUK Sevtap',),
#  ('ALVES Ricardo',),
#  ('AMIRI Hamed',),
#  ('ANDREJCIK Samuel',),
#  ('APPLEGATE Jessica-Jane',),
#  ('ARTS Ilse',)]

# %% [markdown]
# What if you wanted a list of all athletes who had participated in multiple sports?

# %%
# %%sql
#
# SELECT name
# FROM athletes
# WHERE name IN (
#     SELECT name
#     FROM athletes
#     GROUP BY name
#     HAVING COUNT(DISTINCT sport) > 1
# )
# LIMIT 15;
# Out:
#  * postgresql+psycopg://localhost:5432/intro_to_sql_for_analytics
# 15 rows affected.
# [('ABRAHAM GEBRU Daniel',),
#  ('ABRAHAM GEBRU Daniel',),
#  ('ASTASHOV Mikhail',),
#  ('ASTASHOV Mikhail',),
#  ('BANGMA Tristan',),
#  ('BANGMA Tristan',),
#  ('BATE Stephen',),
#  ('BATE Stephen',),
#  ('BEAUGILLET Raphael',),
#  ('BEAUGILLET Raphael',),
#  ('BECK Anna',),
#  ('BECK Anna',),
#  ('BELLIDO GUERRERO Adolfo',),
#  ('BELLIDO GUERRERO Adolfo',),
#  ('BERENYI Joseph',)]

# %% [markdown]
# ## JOIN Subqueries

# %% [markdown]
# You can also use a subquery as part of your JOIN statement if, for example, you want to manipulate data in the right hand (second) table before joining.
#
# Here's a query that will return all the athletes who won a gold medal. It filters the medals table to get only the gold medals and then joins it to the athletes table.

# %%
# %%sql
#
# SELECT date_of_birth, athletes.name, athletes.sport, gold_medals.medal
# FROM athletes
# JOIN (
#     SELECT name, event, medal
#     FROM medals
#     WHERE medal = 'Gold Medal'
# ) AS gold_medals ON athletes.name = gold_medals.name
# LIMIT 15;
# Out:
#  * postgresql+psycopg://localhost:5432/intro_to_sql_for_analytics
# 15 rows affected.
# [(datetime.date(1984, 12, 11), 'ABARZA Alberto', 'Swimming', 'Gold Medal'),
#  (datetime.date(1998, 8, 28), 'ABDELLAOUI Cherine', 'Judo', 'Gold Medal'),
#  (datetime.date(1969, 5, 12), 'ABLINGER Walter', 'Cycling Road', 'Gold Medal'),
#  (datetime.date(1985, 2, 11), 'ABRAHAM GEBRU Daniel', 'Cycling Road', 'Gold Medal'),
#  (datetime.date(1985, 2, 11), 'ABRAHAM GEBRU Daniel', 'Cycling Track', 'Gold Medal'),
#  (datetime.date(1990, 11, 18), 'ADAMS Lisa', 'Athletics', 'Gold Medal'),
#  (datetime.date(1990, 12, 13), 'AFROOZ Saeid', 'Athletics', 'Gold Medal'),
#  (datetime.date(1970, 8, 12), 'ALARYANI Abdulla Sultan', 'Shooting', 'Gold Medal'),
#  (datetime.date(1990, 12, 4), 'ALCOTT Dylan', 'Wheelchair Tennis', 'Gold Medal'),
#  (datetime.date(1984, 12, 12), 'ALI Haider', 'Athletics', 'Gold Medal'),
#  (datetime.date(1989, 6, 13), 'ALI POUR Meisam', 'Sitting Volleyball', 'Gold Medal'),
#  (datetime.date(1985, 5, 6), 'ALIPOURIAN Davoud', 'Sitting Volleyball', 'Gold Medal'),
#  (datetime.date(1994, 3, 29), 'ALONSO MORALES Michelle', 'Swimming', 'Gold Medal'),
#  (datetime.date(1994, 4, 1), 'ALTUNOLUK Sevda', 'Goalball', 'Gold Medal'),
#  (datetime.date(1995, 1, 10), 'ALTUNOLUK Sevtap', 'Goalball', 'Gold Medal')]

# %% [markdown]
# ## SUMMARY
#
# Subqueries can be used in FROM, WHERE and JOIN statements
#  - FROM subqueries allow you to perform some initial manipulations to before filtering and / or aggregating. For example, if you wanted to derive the age of each athlete then filter for people aged 28, you'd need to use a FROM subquery.
# - WHRE subqueries allow you to build dynamic conditions into your queries.
# - JOIN subqueries allow you to perform initial manipulations to the right table, before joining.

# %% [markdown]
# ## Exercise

# %%
# %%sql
#
# SELECT *
# FROM athletes
# LIMIT 10;
# Out:
#  * postgresql+psycopg://localhost:5432/intro_to_sql_for_analytics
# 10 rows affected.
# [(0, 'AAJIM Munkhbat', 'Mongolia', 'MGL', 'Judo', 'JUD', datetime.date(1989, 1, 25), 'Male'),
#  (1, 'ABARZA Alberto', 'Chile', 'CHI', 'Swimming', 'SWM', datetime.date(1984, 12, 11), 'Male'),
#  (2, 'ABASLI Namig', 'Azerbaijan', 'AZE', 'Judo', 'JUD', datetime.date(1997, 9, 12), 'Male'),
#  (3, 'ABASSI Mostefa', 'Algeria', 'ALG', 'Wheelchair Basketball', 'WBK', datetime.date(1977, 9, 25), 'Male'),
#  (4, 'ABBAD Abderraouf', 'Algeria', 'ALG', 'Wheelchair Basketball', 'WBK', datetime.date(1986, 10, 27), 'Male'),
#  (5, 'ABDALLA Ashraf', 'Egypt', 'EGY', 'Sitting Volleyball', 'VBS', datetime.date(1974, 2, 24), 'Male'),
#  (6, 'ABOUELYAZEID Mohamed', 'Egypt', 'EGY', 'Sitting Volleyball', 'VBS', datetime.date(1979, 3, 29), 'Male'),
#  (7, 'ABDELALI Samiha', 'Algeria', 'ALG', 'Wheelchair Basketball', 'WBK', datetime.date(1988, 4, 25), 'Female'),
#  (8, 'ABDELAZIZ Gihan', 'Egypt', 'EGY', 'Powerlifting', 'PWL', datetime.date(1974, 10, 29), 'Female'),
#  (9, 'ELKHARSA Ahmed', 'Egypt', 'EGY', 'Sitting Volleyball', 'VBS', datetime.date(1997, 9, 27), 'Male')]

# %%
# %%sql
#
# SELECT country, COUNT(country) AS athlete_count
# FROM athletes
# GROUP BY country
# ORDER BY athlete_count DESC
# LIMIT 10;
# Out:
#  * postgresql+psycopg://localhost:5432/intro_to_sql_for_analytics
# 10 rows affected.
# [('Japan', 262),
#  ("People's Republic of China", 256),
#  ('RPC', 248),
#  ('United States of America', 243),
#  ('Brazil', 241),
#  ('Great Britain', 221),
#  ('Australia', 181),
#  ('France', 146),
#  ('Ukraine', 139),
#  ('Germany', 137)]

# %%
# %%sql
#
# SELECT *
# FROM medals
# LIMIT 5;
# Out:
#  * postgresql+psycopg://localhost:5432/intro_to_sql_for_analytics
# 5 rows affected.
# [(0, 'Czech Republic', 'CZE', 'DRAHONINSKY David', 'Archery', 'ARC', "Men's Individual - W1", 'Gold Medal'),
#  (1, "People's Republic of China", 'CHN', 'HE Zihao', 'Archery', 'ARC', "Men's Individual Compound - Open", 'Gold Medal'),
#  (2, 'United States of America', 'USA', 'MATHER Kevin', 'Archery', 'ARC', "Men's Individual Recurve - Open", 'Gold Medal'),
#  (3, "People's Republic of China", 'CHN', 'CHEN Minyi', 'Archery', 'ARC', "Women's Individual - W1", 'Gold Medal'),
#  (4, 'Great Britain', 'GBR', 'PATERSON PINE Phoebe', 'Archery', 'ARC', "Women's Individual Compound - Open", 'Gold Medal')]

# %%
# %%sql
#
# SELECT country, COUNT(country) AS medal_count
# FROM medals
# GROUP BY country
# ORDER BY medal_count DESC
# LIMIT 10;
# Out:
#  * postgresql+psycopg://localhost:5432/intro_to_sql_for_analytics
# 10 rows affected.
# [("People's Republic of China", 276),
#  ('Great Britain', 171),
#  ('United States of America', 167),
#  ('RPC', 153),
#  ('Brazil', 111),
#  ('Ukraine', 108),
#  ('Australia', 101),
#  ('Japan', 92),
#  ('Italy', 91),
#  ('Netherlands', 77)]

# %%
# %%sql
#
# SELECT
#     medals_sub.country,
#     athletes_sub.athlete_count,
#     medals_sub.medal_count,
#     ROUND(CAST(medals_sub.medal_count AS numeric) / athletes_sub.athlete_count, 2) AS   medals_per_athlete
# FROM
#         (SELECT country, COUNT(*) AS medal_count FROM medals GROUP BY country) AS medals_sub
# JOIN
#         (SELECT country, COUNT(*) AS athlete_count FROM athletes GROUP BY country) AS athletes_sub
# ON
#         medals_sub.country = athletes_sub.country
# ORDER BY
#         medals_per_athlete DESC
# LIMIT 15;
# Out:
#  * postgresql+psycopg://localhost:5432/intro_to_sql_for_analytics
# 15 rows affected.
# [("People's Republic of China", 256, 276, Decimal('1.08')),
#  ('Netherlands', 74, 77, Decimal('1.04')),
#  ('Italy', 114, 91, Decimal('0.80')),
#  ('Ukraine', 139, 108, Decimal('0.78')),
#  ('Great Britain', 221, 171, Decimal('0.77')),
#  ('Bosnia and Herzegovina', 15, 11, Decimal('0.73')),
#  ('Lithuania', 11, 8, Decimal('0.73')),
#  ('Latvia', 7, 5, Decimal('0.71')),
#  ('United States of America', 243, 167, Decimal('0.69')),
#  ('Switzerland', 21, 14, Decimal('0.67')),
#  ('Namibia', 3, 2, Decimal('0.67')),
#  ('Kuwait', 3, 2, Decimal('0.67')),
#  ('Cyprus', 3, 2, Decimal('0.67')),
#  ('RPC', 248, 153, Decimal('0.62')),
#  ('Islamic Republic of Iran', 63, 35, Decimal('0.56'))]

# %% [markdown]
# The SELECT statement describes what we want as the final output, after the two subqueries and joins have been completed.
#
# We're after a table with 4 columns: country, athlete_count, medal_count and medals_per_athlete.
#
# There are two subqueries - each one is used to aggreate data before the JOIN is executed. In both cases, the data are grouped by country.
#
# Then, finally, we can join the two aggregated tables. The rest is presentational.
